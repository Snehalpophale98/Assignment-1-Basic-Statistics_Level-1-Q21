# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
import statsmodels.api as sm

# %%
data = pd.read_csv("wc-at.csv")
data
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
# Q Q plot
fig = sm.qqplot(data.Waist, line='45')
plt.show()

# %%
# Q Q plot
fig = sm.qqplot(data.AT, line='45')
plt.show()

# %%
# WC
data.Waist.mean() ,data.Waist.median()
# Out:
# (91.90183486238533, 90.8)

# %%
# AT
data.AT.mean() , data.AT.median()
# Out:
# (101.89403669724771, 96.54)

# %%
sns.distplot(data.Waist)
plt.ylabel('Density')
# Out:
# C:\Users\sneha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')

# %%
sns.distplot(data.AT)
plt.ylabel('Density')
# Out:
# C:\Users\sneha\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Density')

# %%
The Q Q plot and distplot shows that the Waist and AT are not distributed normally.
from QQ plot the points are not distributed along the line which shows it is not distributed normally.
